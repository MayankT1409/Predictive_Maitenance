# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('equipment_data.csv')

# %%
df.head()  # Display the first few rows of the dataframe
# Out:
#              Timestamp  Temperature (°C)  Vibration (mm/s)  Pressure (Pa)  \
# 0  2019-01-01 00:00:00          0.548793          0.509840       0.619918
# 1  2019-01-01 01:00:00          0.715185          0.587573       0.802121
# 2  2019-01-01 02:00:00          0.602748          0.294453       0.965546
# 3  2019-01-01 03:00:00          0.544862          0.500041       0.519955
# 4  2019-01-01 04:00:00          0.423622          0.031649       0.323663
#
#         RPM  Maintenance Required  Temp_Change  Vib_Change
# 0  0.741161                     1     0.501129    0.499619
# 1  0.292862                     1     0.584882    0.538630
# 2  0.624416                     1     0.444534    0.352514
# 3  0.931955                     0     0.471992    0.602794
# 4  0.799867                     0     0.440103    0.264552

# %%
df.describe()  # Get a statistical summary of the dataframe
# Out:
#        Temperature (°C)  Vibration (mm/s)  Pressure (Pa)           RPM  \
# count      43800.000000      43800.000000   43800.000000  43800.000000
# mean           0.497752          0.500139       0.502902      0.500764
# std            0.289543          0.288612       0.289589      0.288880
# min            0.000000          0.000000       0.000000      0.000000
# 25%            0.246304          0.248662       0.250924      0.250167
# 50%            0.497589          0.500018       0.504503      0.503002
# 75%            0.749073          0.749795       0.755002      0.749166
# max            1.000000          1.000000       1.000000      1.000000
#
#        Maintenance Required   Temp_Change    Vib_Change
# count          43800.000000  43800.000000  43800.000000
# mean               0.500776      0.501133      0.499622
# std                0.500005      0.206076      0.205033
# min                0.000000      0.000000      0.000000
# ...

# %%
df.isnull().sum()  # Check for missing values in the dataframe
# Out:
# Timestamp               0
# Temperature (°C)        0
# Vibration (mm/s)        0
# Pressure (Pa)           0
# RPM                     0
# Maintenance Required    0
# Temp_Change             0
# Vib_Change              0
# dtype: int64

# %%
df.corr()  # Get the correlation matrix of the dataframe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.corr()  # Get the correlation matrix of the dataframe
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# ...

# %%
df_new = df.drop(columns= ['Timestamp'])

# %%
df_new.corr()  # Get the correlation matrix of the new dataframe without 'Timestamp'
# Out:
#                       Temperature (°C)  Vibration (mm/s)  Pressure (Pa)  \
# Temperature (°C)              1.000000         -0.004103       0.000167
# Vibration (mm/s)             -0.004103          1.000000      -0.004749
# Pressure (Pa)                 0.000167         -0.004749       1.000000
# RPM                          -0.004175         -0.009567      -0.001053
# Maintenance Required         -0.001307          0.004426       0.002288
# Temp_Change                   0.707008          0.006849       0.001684
# Vib_Change                   -0.006027          0.707790       0.002775
#
#                            RPM  Maintenance Required  Temp_Change  Vib_Change
# Temperature (°C)     -0.004175             -0.001307     0.707008   -0.006027
# Vibration (mm/s)     -0.009567              0.004426     0.006849    0.707790
# Pressure (Pa)        -0.001053              0.002288     0.001684    0.002775
# RPM                   1.000000             -0.002704    -0.002509   -0.013184
# ...
